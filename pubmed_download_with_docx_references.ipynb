# %%
# this only kinda works. it's a mess. i'm not sure if it's worth fixing.

import os
import requests
import time
import csv
from Bio import Entrez
import re
from docx import Document
from fuzzywuzzy import fuzz
import PyPDF2
import shutil
import json

def sanitize_filename(filename):
    # Remove invalid characters and truncate to a reasonable length
    invalid_chars = r'[<>:"/\\|?*]'
    sanitized = re.sub(invalid_chars, '', filename)
    return sanitized[:200]

def extract_references_from_docx(file_path):
    doc = Document(file_path)
    full_text = "\n".join([paragraph.text for paragraph in doc.paragraphs])
    references = re.findall(r'\d+\.\s+(.*?)(?=\d+\.\s+|\Z)', full_text, re.DOTALL)
    return [ref.strip() for ref in references]

def extract_info(reference):
    # Improved regex patterns
    title_pattern = r'(?:^|\.\s+)(.+?)\.\s+(?:[A-Za-z\s]+\.)?(?:\s*\(.*?\))?\s*\d'
    authors_pattern = r'^((?:(?:[A-Z][a-z]+(?:,?\s+(?:[A-Z]\.|\([A-Z-]+\))){0,2}(?:,\s+|\s+&\s+))*(?:[A-Z][a-z]+(?:,?\s+(?:[A-Z]\.|\([A-Z-]+\))){0,2})|(?:[A-Z][a-z]+ et al\.)|(?:NCD Risk Factor Collaboration \([^)]+\))))'
    year_pattern = r'\((\d{4})\)'
    doi_pattern = r'doi:?\s*(10\.\d{4,}\/\S+)'
    
    title_match = re.search(title_pattern, reference)
    authors_match = re.match(authors_pattern, reference)
    year_match = re.search(year_pattern, reference)
    doi_match = re.search(doi_pattern, reference)
    
    title = title_match.group(1).strip() if title_match else ''
    authors = authors_match.group(1) if authors_match else ''
    year = year_match.group(1) if year_match else ''
    doi = doi_match.group(1) if doi_match else ''
    
    return {'title': title, 'authors': authors, 'year': year, 'doi': doi}

def clean_string(s):
    return re.sub(r'[^\w\s]', '', s)

def search_pubmed(query, max_results=20):
    Entrez.email = "trentleslie@gmail.com"
    try:
        handle = Entrez.esearch(db='pubmed', 
                                sort='relevance', 
                                retmax=max_results,
                                retmode='xml', 
                                term=query)
        results = Entrez.read(handle)
        handle.close()
        return results
    except Exception as e:
        print(f"Error in search_pubmed: {e}")
        return None

def fetch_article_details(pubmed_id):
    try:
        handle = Entrez.efetch(db='pubmed', id=pubmed_id, rettype='xml', retmode='xml')
        records = Entrez.read(handle)
        handle.close()
        if records['PubmedArticle']:
            return records['PubmedArticle'][0]
        else:
            print(f"No article details found for PubMed ID: {pubmed_id}")
            return None
    except Exception as e:
        print(f"Error in fetch_article_details for PubMed ID {pubmed_id}: {e}")
        return None

def get_pmc_id(article):
    try:
        for id_obj in article['PubmedData']['ArticleIdList']:
            if id_obj.attributes['IdType'] == 'pmc':
                return id_obj
    except KeyError:
        pass
    return None

def download_pdf(pmc_id, output_folder):
    url = f'https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc_id}/pdf'
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            pdf_filename = os.path.join(output_folder, f'{pmc_id}.pdf')
            with open(pdf_filename, 'wb') as f:
                f.write(response.content)
            print(f"Downloaded: {pdf_filename}")
            return pdf_filename
        else:
            print(f"Failed to download PDF for PMC ID: {pmc_id}, Status Code: {response.status_code}")
            return None
    except Exception as e:
        print(f"Error in download_pdf: {e}")
        return None

def verify_pdf(pdf_path, reference):
    try:
        with open(pdf_path, 'rb') as file:
            reader = PyPDF2.PdfReader(file)
            text = ""
            for page in reader.pages[:5]:  # Check first 5 pages
                text += page.extract_text()
            
            ref_info = extract_info(reference)
            title_match = fuzz.partial_ratio(ref_info['title'].lower(), text.lower()) > 70
            authors_match = any(author.lower() in text.lower() for author in ref_info['authors'].split(','))
            year_match = ref_info['year'] in text
            
            return title_match and (authors_match or year_match)
    except Exception as e:
        print(f"Error verifying PDF {pdf_path}: {e}")
        return False

def search_and_download(ref_info, reference, output_folder, rejected_folder, downloaded_pmcs):
    search_strategies = [
        lambda: f'{ref_info["doi"]}' if ref_info["doi"] else None,
        lambda: f'"{ref_info["title"]}"[Title]' if ref_info["title"] else None,
        lambda: f'{ref_info["authors"]}[Author] AND {ref_info["year"]}[Date - Publication] AND "{ref_info["title"]}"[Title]' if ref_info["authors"] and ref_info["year"] and ref_info["title"] else None,
        lambda: f'{ref_info["authors"]}[Author] AND {ref_info["year"]}[Date - Publication]' if ref_info["authors"] and ref_info["year"] else None,
        lambda: f'{" ".join(ref_info["title"].split()[:5])}[Title] AND {ref_info["year"]}[Date - Publication]' if ref_info["title"] and ref_info["year"] else None,
        lambda: f'{ref_info["authors"].split(",")[0]}[Author] AND {ref_info["year"]}[Date - Publication]' if ref_info["authors"] and ref_info["year"] else None,
        lambda: f'{ref_info["title"]}' if ref_info["title"] else None,
        lambda: f'{ref_info["authors"]}' if ref_info["authors"] else None,
    ]

    print(f"\nProcessing reference: {reference}")
    print(f"Extracted info: {json.dumps(ref_info, indent=2)}")

    for i, strategy in enumerate(search_strategies):
        query = strategy()
        if not query:
            print(f"Strategy {i+1}: Skipped (insufficient information)")
            continue
        
        print(f"\nStrategy {i+1}: {query}")
        search_results = search_pubmed(query)
        
        if search_results and int(search_results['Count']) > 0:
            print(f"Search results: {search_results['Count']} articles found")
            for j, pubmed_id in enumerate(search_results['IdList']):
                print(f"\n  Result {j+1}: PubMed ID {pubmed_id}")
                article = fetch_article_details(pubmed_id)
                if article:
                    article_title = article['MedlineCitation']['Article']['ArticleTitle']
                    print(f"  Article title: {article_title}")
                    pmc_id = get_pmc_id(article)
                    if pmc_id:
                        print(f"  PMC ID: {pmc_id}")
                        if pmc_id in downloaded_pmcs:
                            print(f"  PDF already downloaded for PMC ID: {pmc_id}")
                            continue
                        pdf_filename = download_pdf(pmc_id, output_folder)
                        if pdf_filename:
                            print(f"  Downloaded PDF: {pdf_filename}")
                            downloaded_pmcs.add(pmc_id)
                            if verify_pdf(pdf_filename, reference):
                                new_filename = os.path.join(output_folder, f"{sanitize_filename(reference)}.pdf")
                                os.rename(pdf_filename, new_filename)
                                print(f"  Verified and renamed: {pdf_filename} -> {new_filename}")
                                return new_filename
                            else:
                                rejected_filename = os.path.join(rejected_folder, f"{sanitize_filename(reference)}.pdf")
                                shutil.move(pdf_filename, rejected_filename)
                                print(f"  Verification failed. Moved to: {rejected_filename}")
                    else:
                        print("  No PMC ID available")
                else:
                    print("  Failed to fetch article details")
        else:
            print("No results found")
        
        time.sleep(0.5)  # Sleep to respect API rate limits
    
    print("All strategies exhausted. No matching PDF found.")
    return None


def main():
    docx_file_path = '/home/trent/github/QuickTools/57ISB15US - REFERENCES (1).docx'  # Replace with the path to your DOCX file
    output_folder = './pdf_downloads'  # Folder where verified PDFs will be saved
    rejected_folder = './rejected_pdfs'  # Folder for rejected PDFs
    csv_output_file = 'download_results.csv'  # CSV file to store results
    
    os.makedirs(output_folder, exist_ok=True)
    os.makedirs(rejected_folder, exist_ok=True)
    
    references = extract_references_from_docx(docx_file_path)
    
    results = []
    downloaded_pmcs = set()  # Set to keep track of downloaded PMC IDs
    
    for ref in references:
        print(f"Processing: {ref}")
        ref_info = extract_info(ref)
        
        pdf_filename = search_and_download(ref_info, ref, output_folder, rejected_folder, downloaded_pmcs)
        
        if pdf_filename:
            results.append({'Reference': ref, 'Downloaded': 'Yes', 'Reason': 'PDF downloaded, verified, and renamed', 'Filename': os.path.basename(pdf_filename)})
        else:
            results.append({'Reference': ref, 'Downloaded': 'No', 'Reason': 'Failed to find, download, or verify PDF', 'Filename': ''})
    
    # Write results to CSV
    with open(csv_output_file, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['Reference', 'Downloaded', 'Reason', 'Filename']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for row in results:
            writer.writerow(row)
    
    print(f"Results saved to {csv_output_file}")

if __name__ == '__main__':
    main()
# Out:
# Processing: NCD Risk Factor Collaboration (NCD-RisC). Trends in adult body-mass index in 200 countries from 1975 to 2014: a pooled analysis of 1698 population-based measurement studies with 19·2 million participants. Lancet (London, England) 387, 1377–1396 (2016).
#
# Processing reference: NCD Risk Factor Collaboration (NCD-RisC). Trends in adult body-mass index in 200 countries from 1975 to 2014: a pooled analysis of 1698 population-based measurement studies with 19·2 million participants. Lancet (London, England) 387, 1377–1396 (2016).
# Extracted info: {
#   "title": "",
#   "authors": "NCD Risk Factor Collaboration (NCD-RisC)",
#   "year": "2016",
#   "doi": ""
# }
# Strategy 1: Skipped (insufficient information)
# Strategy 2: Skipped (insufficient information)
# Strategy 3: Skipped (insufficient information)
#
# Strategy 4: NCD Risk Factor Collaboration (NCD-RisC)[Author] AND 2016[Date - Publication]
# No results found
# Strategy 5: Skipped (insufficient information)
#
# Strategy 6: NCD Risk Factor Collaboration (NCD-RisC)[Author] AND 2016[Date - Publication]
# No results found
# Strategy 7: Skipped (insufficient information)
#
# Strategy 8: NCD Risk Factor Collaboration (NCD-RisC)
# Search results: 26 articles found
#
#   Result 1: PubMed ID 34450083
#   Article title: Worldwide trends in hypertension prevalence and progress in treatment and control from 1990 to 2019: a pooled analysis of 1201 population-representative studies with 104 million participants.
#   PMC ID: PMC8446938
# Failed to download PDF for PMC ID: PMC8446938, Status Code: 404
#
#   Result 2: PubMed ID 29029897
#   Article title: Worldwide trends in body-mass index, underweight, overweight, and obesity from 1975 to 2016: a pooled analysis of 2416 population-based measurement studies in 128·9 million children, adolescents, and adults.
#   PMC ID: PMC5735219
# Downloaded: ./pdf_downloads/PMC5735219.pdf
#   Downloaded PDF: ./pdf_downloads/PMC5735219.pdf
#   Verification failed. Moved to: ./rejected_pdfs/NCD Risk Factor Collaboration (NCD-RisC). Trends in adult body-mass index in 200 countries from 1975 to 2014 a pooled analysis of 1698 population-based measurement studies with 19·2 million participan.pdf
#
#   Result 3: PubMed ID 38432237
#   Article title: Worldwide trends in underweight and obesity from 1990 to 2022: a pooled analysis of 3663 population-representative studies with 222 million children, adolescents, and adults.
#   PMC ID: PMC7615769
# Downloaded: ./pdf_downloads/PMC7615769.pdf
#   Downloaded PDF: ./pdf_downloads/PMC7615769.pdf
#   Verification failed. Moved to: ./rejected_pdfs/NCD Risk Factor Collaboration (NCD-RisC). Trends in adult body-mass index in 200 countries from 1975 to 2014 a pooled analysis of 1698 population-based measurement studies with 19·2 million participan.pdf
#
#   Result 4: PubMed ID 27115820
#   Article title: Trends in adult body-mass index in 200 countries from 1975 to 2014: a pooled analysis of 1698 population-based measurement studies with 19·2 million participants.
#   PMC ID: PMC7615134
# Downloaded: ./pdf_downloads/PMC7615134.pdf
#   Downloaded PDF: ./pdf_downloads/PMC7615134.pdf
#   Verification failed. Moved to: ./rejected_pdfs/NCD Risk Factor Collaboration (NCD-RisC). Trends in adult body-mass index in 200 countries from 1975 to 2014 a pooled analysis of 1698 population-based measurement studies with 19·2 million participan.pdf
#
#   Result 5: PubMed ID 27061677
#   Article title: Worldwide trends in diabetes since 1980: a pooled analysis of 751 population-based studies with 4.4 million participants.
#   PMC ID: PMC5081106
# Downloaded: ./pdf_downloads/PMC5081106.pdf
#   Downloaded PDF: ./pdf_downloads/PMC5081106.pdf
#   Verification failed. Moved to: ./rejected_pdfs/NCD Risk Factor Collaboration (NCD-RisC). Trends in adult body-mass index in 200 countries from 1975 to 2014 a pooled analysis of 1698 population-based measurement studies with 19·2 million participan.pdf
#
#   Result 6: PubMed ID 32494083
#   Article title: Repositioning of the global epicentre of non-optimal cholesterol.
#   PMC ID: PMC7332422
# Downloaded: ./pdf_downloads/PMC7332422.pdf
#   Downloaded PDF: ./pdf_downloads/PMC7332422.pdf
#   Verification failed. Moved to: ./rejected_pdfs/NCD Risk Factor Collaboration (NCD-RisC). Trends in adult body-mass index in 200 countries from 1975 to 2014 a pooled analysis of 1698 population-based measurement studies with 19·2 million participan.pdf
#
#   Result 7: PubMed ID 33160572
#   Article title: Height and body-mass index trajectories of school-aged children and adolescents from 1985 to 2019 in 200 countries and territories: a pooled analysis of 2181 population-based studies with 65 million participants.
#   PMC ID: PMC7658740
# Downloaded: ./pdf_downloads/PMC7658740.pdf
#   Downloaded PDF: ./pdf_downloads/PMC7658740.pdf
#   Verification failed. Moved to: ./rejected_pdfs/NCD Risk Factor Collaboration (NCD-RisC). Trends in adult body-mass index in 200 countries from 1975 to 2014 a pooled analysis of 1698 population-based measurement studies with 19·2 million participan.pdf
#
#   Result 8: PubMed ID 27863813
#   Article title: Worldwide trends in blood pressure from 1975 to 2015: a pooled analysis of 1479 population-based measurement studies with 19·1 million participants.
#   PMC ID: PMC5220163
# Downloaded: ./pdf_downloads/PMC5220163.pdf
#   Downloaded PDF: ./pdf_downloads/PMC5220163.pdf
#   Verification failed. Moved to: ./rejected_pdfs/NCD Risk Factor Collaboration (NCD-RisC). Trends in adult body-mass index in 200 countries from 1975 to 2014 a pooled analysis of 1698 population-based measurement studies with 19·2 million participan.pdf
#
#   Result 9: PubMed ID 33685583
#   Article title: Heterogeneous contributions of change in population distribution of body mass index to change in obesity and underweight.
#   PMC ID: PMC7943191
# Downloaded: ./pdf_downloads/PMC7943191.pdf
#   Downloaded PDF: ./pdf_downloads/PMC7943191.pdf
#   Verification failed. Moved to: ./rejected_pdfs/NCD Risk Factor Collaboration (NCD-RisC). Trends in adult body-mass index in 200 countries from 1975 to 2014 a pooled analysis of 1698 population-based measurement studies with 19·2 million participan.pdf
#
#   Result 10: PubMed ID 36991188
#   Article title: Diminishing benefits of urban living for children and adolescents' growth and development.
#   PMC ID: PMC10060164
# Downloaded: ./pdf_downloads/PMC10060164.pdf
#   Downloaded PDF: ./pdf_downloads/PMC10060164.pdf
#   Verification failed. Moved to: ./rejected_pdfs/NCD Risk Factor Collaboration (NCD-RisC). Trends in adult body-mass index in 200 countries from 1975 to 2014 a pooled analysis of 1698 population-based measurement studies with 19·2 million participan.pdf
#
#   Result 11: PubMed ID 37946056
#   Article title: Global variation in diabetes diagnosis and prevalence based on fasting glucose and hemoglobin A1c.
#   PMC ID: PMC10667106
# Downloaded: ./pdf_downloads/PMC10667106.pdf
#   Downloaded PDF: ./pdf_downloads/PMC10667106.pdf
#   Verification failed. Moved to: ./rejected_pdfs/NCD Risk Factor Collaboration (NCD-RisC). Trends in adult body-mass index in 200 countries from 1975 to 2014 a pooled analysis of 1698 population-based measurement studies with 19·2 million participan.pdf
#
#   Result 12: PubMed ID 35569084
#   Article title: Trends in obesity-related cancer burden in Czechia.
#   No PMC ID available
#
#   Result 13: PubMed ID 33574565
#   Article title: Secondary analyses of global datasets: do obesity and physical activity explain variation in diabetes risk across populations?
#   PMC ID: PMC8081659
# Downloaded: ./pdf_downloads/PMC8081659.pdf
#   Downloaded PDF: ./pdf_downloads/PMC8081659.pdf
#   Verification failed. Moved to: ./rejected_pdfs/NCD Risk Factor Collaboration (NCD-RisC). Trends in adult body-mass index in 200 countries from 1975 to 2014 a pooled analysis of 1698 population-based measurement studies with 19·2 million participan.pdf
#
#   Result 14: PubMed ID 31068725
#   Article title: Rising rural body-mass index is the main driver of the global obesity epidemic in adults.
#   PMC ID: PMC6784868
# Downloaded: ./pdf_downloads/PMC6784868.pdf
#   Downloaded PDF: ./pdf_downloads/PMC6784868.pdf
#   Verification failed. Moved to: ./rejected_pdfs/NCD Risk Factor Collaboration (NCD-RisC). Trends in adult body-mass index in 200 countries from 1975 to 2014 a pooled analysis of 1698 population-based measurement studies with 19·2 million participan.pdf
#
#   Result 15: PubMed ID 34548066
#   Article title: COVID-19, body mass index and cholesterol: an ecological study using global data.
#   PMC ID: PMC8453032
# Downloaded: ./pdf_downloads/PMC8453032.pdf
#   Downloaded PDF: ./pdf_downloads/PMC8453032.pdf
#   Verification failed. Moved to: ./rejected_pdfs/NCD Risk Factor Collaboration (NCD-RisC). Trends in adult body-mass index in 200 countries from 1975 to 2014 a pooled analysis of 1698 population-based measurement studies with 19·2 million participan.pdf
#
#   Result 16: PubMed ID 33075798
#   Article title: Obesity Prevalence in the Long-Term Future in 18 European Countries and in the USA.
#   PMC ID: PMC7670332
# Downloaded: ./pdf_downloads/PMC7670332.pdf
#   Downloaded PDF: ./pdf_downloads/PMC7670332.pdf
#   Verification failed. Moved to: ./rejected_pdfs/NCD Risk Factor Collaboration (NCD-RisC). Trends in adult body-mass index in 200 countries from 1975 to 2014 a pooled analysis of 1698 population-based measurement studies with 19·2 million participan.pdf
#
#   Result 17: PubMed ID 34302914
#   Article title: Long-term trends of BMI and cardiometabolic risk factors among adults with type 1 diabetes: An observational study from the German/Austrian DPV registry.
#   No PMC ID available
#
#   Result 18: PubMed ID 39091655
#   Article title: Global burden of adult non-alcoholic fatty liver disease (NAFLD) and non-alcoholic steatohepatitis (NASH) has been steadily increasing over the past decades and is expected to persist in the future.
#   PMC ID: PMC11292082
# Downloaded: ./pdf_downloads/PMC11292082.pdf
#   Downloaded PDF: ./pdf_downloads/PMC11292082.pdf
#   Verification failed. Moved to: ./rejected_pdfs/NCD Risk Factor Collaboration (NCD-RisC). Trends in adult body-mass index in 200 countries from 1975 to 2014 a pooled analysis of 1698 population-based measurement studies with 19·2 million participan.pdf
#
#   Result 19: PubMed ID 28199042
#   Article title: Global effects of income and income inequality on adult height and sexual dimorphism in height.
#   No PMC ID available
#
#   Result 20: PubMed ID 27458798
#   Article title: A century of trends in adult human height.
#   PMC ID: PMC4961475
# Downloaded: ./pdf_downloads/PMC4961475.pdf
#   Downloaded PDF: ./pdf_downloads/PMC4961475.pdf
#   Verification failed. Moved to: ./rejected_pdfs/NCD Risk Factor Collaboration (NCD-RisC). Trends in adult body-mass index in 200 countries from 1975 to 2014 a pooled analysis of 1698 population-based measurement studies with 19·2 million participan.pdf
# All strategies exhausted. No matching PDF found.
# Processing: NCD Risk Factor Collaboration (NCD-RisC). Worldwide trends in body-mass index, underweight, overweight, and obesity from 1975 to 2016: a pooled analysis of 2416 population-based measurement studies in 128·9 million children, adolescents, and adults. Lancet (London, England) 390, 2627–2642 (2017).
#
# Processing reference: NCD Risk Factor Collaboration (NCD-RisC). Worldwide trends in body-mass index, underweight, overweight, and obesity from 1975 to 2016: a pooled analysis of 2416 population-based measurement studies in 128·9 million children, adolescents, and adults. Lancet (London, England) 390, 2627–2642 (2017).
# Extracted info: {
#   "title": "",
#   "authors": "NCD Risk Factor Collaboration (NCD-RisC)",
#   "year": "2017",
#   "doi": ""
# }
# Strategy 1: Skipped (insufficient information)
# Strategy 2: Skipped (insufficient information)
# Strategy 3: Skipped (insufficient information)
#
# Strategy 4: NCD Risk Factor Collaboration (NCD-RisC)[Author] AND 2017[Date - Publication]
# No results found
# Strategy 5: Skipped (insufficient information)
#
# Strategy 6: NCD Risk Factor Collaboration (NCD-RisC)[Author] AND 2017[Date - Publication]
# No results found
# Strategy 7: Skipped (insufficient information)
#
# Strategy 8: NCD Risk Factor Collaboration (NCD-RisC)
# Search results: 26 articles found
#
#   Result 1: PubMed ID 34450083
#   Article title: Worldwide trends in hypertension prevalence and progress in treatment and control from 1990 to 2019: a pooled analysis of 1201 population-representative studies with 104 million participants.
#   PMC ID: PMC8446938
# Failed to download PDF for PMC ID: PMC8446938, Status Code: 404
#
#   Result 2: PubMed ID 29029897
#   Article title: Worldwide trends in body-mass index, underweight, overweight, and obesity from 1975 to 2016: a pooled analysis of 2416 population-based measurement studies in 128·9 million children, adolescents, and adults.
#   PMC ID: PMC5735219
#   PDF already downloaded for PMC ID: PMC5735219
#
#   Result 3: PubMed ID 38432237
#   Article title: Worldwide trends in underweight and obesity from 1990 to 2022: a pooled analysis of 3663 population-representative studies with 222 million children, adolescents, and adults.
#   PMC ID: PMC7615769
#   PDF already downloaded for PMC ID: PMC7615769
#
#   Result 4: PubMed ID 27115820
#   Article title: Trends in adult body-mass index in 200 countries from 1975 to 2014: a pooled analysis of 1698 population-based measurement studies with 19·2 million participants.
#   PMC ID: PMC7615134
#   PDF already downloaded for PMC ID: PMC7615134
#
#   Result 5: PubMed ID 27061677
#   Article title: Worldwide trends in diabetes since 1980: a pooled analysis of 751 population-based studies with 4.4 million participants.
#   PMC ID: PMC5081106
#   PDF already downloaded for PMC ID: PMC5081106
#
#   Result 6: PubMed ID 32494083
#   Article title: Repositioning of the global epicentre of non-optimal cholesterol.
#   PMC ID: PMC7332422
#   PDF already downloaded for PMC ID: PMC7332422
#
#   Result 7: PubMed ID 33160572
#   Article title: Height and body-mass index trajectories of school-aged children and adolescents from 1985 to 2019 in 200 countries and territories: a pooled analysis of 2181 population-based studies with 65 million participants.
#   PMC ID: PMC7658740
#   PDF already downloaded for PMC ID: PMC7658740
#
#   Result 8: PubMed ID 27863813
#   Article title: Worldwide trends in blood pressure from 1975 to 2015: a pooled analysis of 1479 population-based measurement studies with 19·1 million participants.
#   PMC ID: PMC5220163
#   PDF already downloaded for PMC ID: PMC5220163
#
#   Result 9: PubMed ID 33685583
#   Article title: Heterogeneous contributions of change in population distribution of body mass index to change in obesity and underweight.
#   PMC ID: PMC7943191
#   PDF already downloaded for PMC ID: PMC7943191
#
#   Result 10: PubMed ID 36991188
#   Article title: Diminishing benefits of urban living for children and adolescents' growth and development.
#   PMC ID: PMC10060164
#   PDF already downloaded for PMC ID: PMC10060164
#
#   Result 11: PubMed ID 37946056
#   Article title: Global variation in diabetes diagnosis and prevalence based on fasting glucose and hemoglobin A1c.
#   PMC ID: PMC10667106
#   PDF already downloaded for PMC ID: PMC10667106
#
#   Result 12: PubMed ID 35569084
#   Article title: Trends in obesity-related cancer burden in Czechia.
#   No PMC ID available
#
#   Result 13: PubMed ID 33574565
#   Article title: Secondary analyses of global datasets: do obesity and physical activity explain variation in diabetes risk across populations?
#   PMC ID: PMC8081659
#   PDF already downloaded for PMC ID: PMC8081659
#
#   Result 14: PubMed ID 31068725
#   Article title: Rising rural body-mass index is the main driver of the global obesity epidemic in adults.
#   PMC ID: PMC6784868
#   PDF already downloaded for PMC ID: PMC6784868
#
#   Result 15: PubMed ID 34548066
#   Article title: COVID-19, body mass index and cholesterol: an ecological study using global data.
#   PMC ID: PMC8453032
#   PDF already downloaded for PMC ID: PMC8453032
#
#   Result 16: PubMed ID 33075798
#   Article title: Obesity Prevalence in the Long-Term Future in 18 European Countries and in the USA.
#   PMC ID: PMC7670332
#   PDF already downloaded for PMC ID: PMC7670332
#
#   Result 17: PubMed ID 34302914
#   Article title: Long-term trends of BMI and cardiometabolic risk factors among adults with type 1 diabetes: An observational study from the German/Austrian DPV registry.
#   No PMC ID available
#
#   Result 18: PubMed ID 39091655
#   Article title: Global burden of adult non-alcoholic fatty liver disease (NAFLD) and non-alcoholic steatohepatitis (NASH) has been steadily increasing over the past decades and is expected to persist in the future.
#   PMC ID: PMC11292082
#   PDF already downloaded for PMC ID: PMC11292082
#
#   Result 19: PubMed ID 28199042
#   Article title: Global effects of income and income inequality on adult height and sexual dimorphism in height.
#   No PMC ID available
#
#   Result 20: PubMed ID 27458798
#   Article title: A century of trends in adult human height.
#   PMC ID: PMC4961475
#   PDF already downloaded for PMC ID: PMC4961475
# All strategies exhausted. No matching PDF found.
# Processing: Kopelman, P. G. Obesity as a medical problem. Nature 404, 635–43 (2000).
#
# Processing reference: Kopelman, P. G. Obesity as a medical problem. Nature 404, 635–43 (2000).
# Extracted info: {
#   "title": "",
#   "authors": "Kopelman, P. G.",
#   "year": "2000",
#   "doi": ""
# }
# Strategy 1: Skipped (insufficient information)
# Strategy 2: Skipped (insufficient information)
# Strategy 3: Skipped (insufficient information)
#
# Strategy 4: Kopelman, P. G.[Author] AND 2000[Date - Publication]
# Search results: 4 articles found
#
#   Result 1: PubMed ID 10997622
#   Article title: Physiopathology of prolactin secretion in obesity.
#   No PMC ID available
#
#   Result 2: PubMed ID 10766250
#   Article title: Obesity as a medical problem.
#   No PMC ID available
#
#   Result 3: PubMed ID 10757623
#   Article title: One-year treatment of obesity: a randomized, double-blind, placebo-controlled, multicentre study of orlistat, a gastrointestinal lipase inhibitor.
#   No PMC ID available
#
#   Result 4: PubMed ID 11151767
#   Article title: Evidence that single nucleotide polymorphism in the uncoupling protein 3 (UCP3) gene influences fat distribution in women of European and Asian origin.
#   No PMC ID available
# Strategy 5: Skipped (insufficient information)
#
# Strategy 6: Kopelman[Author] AND 2000[Date - Publication]
# Search results: 29 articles found
#
#   Result 1: PubMed ID 10997622
#   Article title: Physiopathology of prolactin secretion in obesity.
#   No PMC ID available
#
#   Result 2: PubMed ID 10766250
#   Article title: Obesity as a medical problem.
#   No PMC ID available
#
#   Result 3: PubMed ID 11035851
#   Article title: Reply.
#   No PMC ID available
#
#   Result 4: PubMed ID 10710601
#   Article title: Obituaries.
#   PMC ID: PMC1117730
# Downloaded: ./pdf_downloads/PMC1117730.pdf
#   Downloaded PDF: ./pdf_downloads/PMC1117730.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Kopelman, P. G. Obesity as a medical problem. Nature 404, 635–43 (2000)..pdf
#
#   Result 5: PubMed ID 10892362
#   Article title: Helicobacter pylori: seroprevalence and colorectal cancer.
#   No PMC ID available
#
#   Result 6: PubMed ID 11262635
#   Article title: Children as research subjects: a dilemma.
#   No PMC ID available
#
#   Result 7: PubMed ID 10752771
#   Article title: The treatment of primary palmar hyperhidrosis: a review.
#   No PMC ID available
#
#   Result 8: PubMed ID 10757623
#   Article title: One-year treatment of obesity: a randomized, double-blind, placebo-controlled, multicentre study of orlistat, a gastrointestinal lipase inhibitor.
#   No PMC ID available
#
#   Result 9: PubMed ID 10692611
#   Article title: Differences in pain expression between male and female newborn infants.
#   No PMC ID available
#
#   Result 10: PubMed ID 20945196
#   Article title: Focal retrograde amnesia and the attribution of causality: An exceptionally critical view.
#   No PMC ID available
#
#   Result 11: PubMed ID 10920656
#   Article title: Laboratory testing for preeclampsia: result trends and screening recommendations.
#   No PMC ID available
#
#   Result 12: PubMed ID 11030853
#   Article title: The recognition of facial expression of pain in full-term newborns by parents and health professionals.
#   No PMC ID available
#
#   Result 13: PubMed ID 10860620
#   Article title: Cryohemostasis of uncontrolled hemorrhage from liver injury.
#   No PMC ID available
#
#   Result 14: PubMed ID 10740153
#   Article title: Long-term follow-up of patients requiring intravenous amiodarone to suppress hemodynamically destabilizing ventricular arrhythmias.
#   No PMC ID available
#
#   Result 15: PubMed ID 11191537
#   Article title: Effect of sibutramine on weight maintenance after weight loss: a randomised trial. STORM Study Group. Sibutramine Trial of Obesity Reduction and Maintenance.
#   No PMC ID available
#
#   Result 16: PubMed ID 11022357
#   Article title: [Airway pressure release in postoperative cardiac surgery in pediatric patients].
#   No PMC ID available
#
#   Result 17: PubMed ID 10755059
#   Article title: Rapid eye movement sleep behaviour disorder, depression and cognitive impairment. Case study.
#   No PMC ID available
#
#   Result 18: PubMed ID 11193740
#   Article title: The effect of upper dorsal thoracoscopic sympathectomy on the total amount of body perspiration.
#   No PMC ID available
#
#   Result 19: PubMed ID 11175566
#   Article title: [Dosage of atrial natriuretic peptide in pediatric patients submitted to mechanical ventilation].
#   No PMC ID available
#
#   Result 20: PubMed ID 11151767
#   Article title: Evidence that single nucleotide polymorphism in the uncoupling protein 3 (UCP3) gene influences fat distribution in women of European and Asian origin.
#   No PMC ID available
# Strategy 7: Skipped (insufficient information)
#
# Strategy 8: Kopelman, P. G.
# Search results: 77 articles found
#
#   Result 1: PubMed ID 8959072
#   Article title: Obesity genes.
#   No PMC ID available
#
#   Result 2: PubMed ID 15475229
#   Article title: Medical consequences of obesity.
#   No PMC ID available
#
#   Result 3: PubMed ID 14604901
#   Article title: Preventing diabetes in south Asians.
#   PMC ID: PMC261729
# Downloaded: ./pdf_downloads/PMC261729.pdf
#   Downloaded PDF: ./pdf_downloads/PMC261729.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Kopelman, P. G. Obesity as a medical problem. Nature 404, 635–43 (2000)..pdf
#
#   Result 4: PubMed ID 9872152
#   Article title: Diabetes. Exploding type II.
#   No PMC ID available
#
#   Result 5: PubMed ID 6391758
#   Article title: Clinical complications of obesity.
#   No PMC ID available
#
#   Result 6: PubMed ID 10766250
#   Article title: Obesity as a medical problem.
#   No PMC ID available
#
#   Result 7: PubMed ID 10997622
#   Article title: Physiopathology of prolactin secretion in obesity.
#   No PMC ID available
#
#   Result 8: PubMed ID 7980347
#   Article title: Hormones and obesity.
#   No PMC ID available
#
#   Result 9: PubMed ID 9246839
#   Article title: Obesity, non-insulin-dependent diabetes mellitus and the metabolic syndrome.
#   No PMC ID available
#
#   Result 10: PubMed ID 17370714
#   Article title: Medical management of obesity.
#   No PMC ID available
#
#   Result 11: PubMed ID 12508955
#   Article title: Cardiovascular risks in obesity.
#   No PMC ID available
#
#   Result 12: PubMed ID 3075931
#   Article title: Neuroendocrine function in obesity.
#   No PMC ID available
#
#   Result 13: PubMed ID 15194659
#   Article title: New thoughts on managing obesity.
#   PMC ID: PMC1774129
# Downloaded: ./pdf_downloads/PMC1774129.pdf
#   Downloaded PDF: ./pdf_downloads/PMC1774129.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Kopelman, P. G. Obesity as a medical problem. Nature 404, 635–43 (2000)..pdf
#
#   Result 14: PubMed ID 15481759
#   Article title: The effects of weight loss treatments on upper and lower body fat.
#   No PMC ID available
#
#   Result 15: PubMed ID 10090142
#   Article title: Is the hypothalamic-pituitary-adrenal axis really hyperactivated in visceral obesity?
#   No PMC ID available
#
#   Result 16: PubMed ID 8044191
#   Article title: ASO consensus statement on obesity. UK Association for the Study of Obesity.
#   No PMC ID available
#
#   Result 17: PubMed ID 9758238
#   Article title: Emerging management strategies for obesity.
#   No PMC ID available
#
#   Result 18: PubMed ID 7889602
#   Article title: Investigation of obesity.
#   No PMC ID available
#
#   Result 19: PubMed ID 1889145
#   Article title: An association between hypothalamic-pituitary dysfunction and peripheral endocrine function in extreme obesity.
#   No PMC ID available
#
#   Result 20: PubMed ID 8227802
#   Article title: Silent myocardial ischemia: role of subclinical neuropathy in patients with and without diabetes.
#   No PMC ID available
# All strategies exhausted. No matching PDF found.
# Processing: Haslam, D. W. & James, W. P. T. Obesity. Lancet (London, England) 366, 1197–209 (2005).
#
# Processing reference: Haslam, D. W. & James, W. P. T. Obesity. Lancet (London, England) 366, 1197–209 (2005).
# Extracted info: {
#   "title": "",
#   "authors": "Haslam, D. W. & James, W. P.",
#   "year": "2005",
#   "doi": ""
# }
# Strategy 1: Skipped (insufficient information)
# Strategy 2: Skipped (insufficient information)
# Strategy 3: Skipped (insufficient information)
#
# Strategy 4: Haslam, D. W. & James, W. P.[Author] AND 2005[Date - Publication]
# Search results: 1 articles found
#
#   Result 1: PubMed ID 16198769
#   Article title: Obesity.
#   No PMC ID available
# Strategy 5: Skipped (insufficient information)
#
# Strategy 6: Haslam[Author] AND 2005[Date - Publication]
# Search results: 46 articles found
#
#   Result 1: PubMed ID 16198769
#   Article title: Obesity.
#   No PMC ID available
#
#   Result 2: PubMed ID 16917138
#   Article title: Progestins and breast cancer.
#   No PMC ID available
#
#   Result 3: PubMed ID 16235354
#   Article title: Antioxidants for preventing pre-eclampsia.
#   No PMC ID available
#
#   Result 4: PubMed ID 16917135
#   Article title: Introduction.
#   No PMC ID available
#
#   Result 5: PubMed ID 16917140
#   Article title: Experimental mouse model of hormonal therapy effects on the postmenopausal mammary gland.
#   No PMC ID available
#
#   Result 6: PubMed ID 16087502
#   Article title: Good vibrations: do electrical therapeutic massagers work?
#   No PMC ID available
#
#   Result 7: PubMed ID 15798506
#   Article title: Exploring the role of an acute pain specialist nurse in the Royal Navy.
#   No PMC ID available
#
#   Result 8: PubMed ID 16046606
#   Article title: Perceptions of the impact of depression and anxiety and the medication for these conditions on safety in the workplace.
#   PMC ID: PMC1741070
# Downloaded: ./pdf_downloads/PMC1741070.pdf
#   Downloaded PDF: ./pdf_downloads/PMC1741070.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Haslam, D. W. & James, W. P. T. Obesity. Lancet (London, England) 366, 1197–209 (2005)..pdf
#
#   Result 9: PubMed ID 16237199
#   Article title: A focused microarray approach to functional glycomics: transcriptional regulation of the glycome.
#   No PMC ID available
#
#   Result 10: PubMed ID 15892935
#   Article title: Contributing factors in construction accidents.
#   No PMC ID available
#
#   Result 11: PubMed ID 16077055
#   Article title: Predisplacement and postdisplacement factors associated with mental health of refugees and internally displaced persons: a meta-analysis.
#   No PMC ID available
#
#   Result 12: PubMed ID 16238844
#   Article title: Taking the strain: social identity, social support, and the experience of stress.
#   No PMC ID available
#
#   Result 13: PubMed ID 15705852
#   Article title: Glycolipids as receptors for Bacillus thuringiensis crystal toxin.
#   No PMC ID available
#
#   Result 14: PubMed ID 16192432
#   Article title: A quantitative and highly sensitive luciferase-based assay for bacterial toxins that inhibit protein synthesis.
#   No PMC ID available
#
#   Result 15: PubMed ID 15878961
#   Article title: Progesterone receptor isoforms A and B: temporal and spatial differences in expression during murine mammary gland development.
#   No PMC ID available
#
#   Result 16: PubMed ID 16163827
#   Article title: Transcriptomics and proteomics: tools for optimising phytoremediation activities.
#   No PMC ID available
#
#   Result 17: PubMed ID 16393026
#   Article title: More human than you: attributing humanness to self and others.
#   No PMC ID available
#
#   Result 18: PubMed ID 15784599
#   Article title: Shiga toxin is transported from the endoplasmic reticulum following interaction with the luminal chaperone HEDJ/ERdj3.
#   PMC ID: PMC1087411
# Downloaded: ./pdf_downloads/PMC1087411.pdf
#   Downloaded PDF: ./pdf_downloads/PMC1087411.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Haslam, D. W. & James, W. P. T. Obesity. Lancet (London, England) 366, 1197–209 (2005)..pdf
#
#   Result 19: PubMed ID 15620883
#   Article title: Estimating the number of viable animal cells in multiwell culture--a tetrazolium-based assay.
#   No PMC ID available
#
#   Result 20: PubMed ID 16122810
#   Article title: Anxiety and depression in the workplace: effects on the individual and organisation (a focus group investigation).
#   No PMC ID available
# Strategy 7: Skipped (insufficient information)
#
# Strategy 8: Haslam, D. W. & James, W. P.
# Search results: 2 articles found
#
#   Result 1: PubMed ID 16198769
#   Article title: Obesity.
#   No PMC ID available
#
#   Result 2: PubMed ID 20818901
#   Article title: Effect of sibutramine on cardiovascular outcomes in overweight and obese subjects.
#   No PMC ID available
# All strategies exhausted. No matching PDF found.
# Processing: Kahn, S. E., Hull, R. L. & Utzschneider, K. M. Mechanisms linking obesity to insulin resistance and type 2 diabetes. Nature 444, 840–6 (2006).
#
# Processing reference: Kahn, S. E., Hull, R. L. & Utzschneider, K. M. Mechanisms linking obesity to insulin resistance and type 2 diabetes. Nature 444, 840–6 (2006).
# Extracted info: {
#   "title": "",
#   "authors": "Kahn, S. E., Hull, R. L. & Utzschneider, K. M.",
#   "year": "2006",
#   "doi": ""
# }
# Strategy 1: Skipped (insufficient information)
# Strategy 2: Skipped (insufficient information)
# Strategy 3: Skipped (insufficient information)
#
# Strategy 4: Kahn, S. E., Hull, R. L. & Utzschneider, K. M.[Author] AND 2006[Date - Publication]
# Search results: 4 articles found
#
#   Result 1: PubMed ID 17167471
#   Article title: Mechanisms linking obesity to insulin resistance and type 2 diabetes.
#   No PMC ID available
#
#   Result 2: PubMed ID 17141914
#   Article title: Superiority of the Modification of Diet in Renal Disease equation over the Cockcroft-Gault equation in screening for impaired kidney function in Japanese Americans.
#   PMC ID: PMC1995414
# Downloaded: ./pdf_downloads/PMC1995414.pdf
#   Downloaded PDF: ./pdf_downloads/PMC1995414.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Kahn, S. E., Hull, R. L. & Utzschneider, K. M. Mechanisms linking obesity to insulin resistance and type 2 diabetes. Nature 444, 840–6 (2006)..pdf
#
#   Result 3: PubMed ID 16443887
#   Article title: Impact of differences in fasting glucose and glucose tolerance on the hyperbolic relationship between insulin sensitivity and insulin responses.
#   No PMC ID available
#
#   Result 4: PubMed ID 16936156
#   Article title: Gestational diabetes mellitus increases the risk of cardiovascular disease in women with a family history of type 2 diabetes.
#   No PMC ID available
# Strategy 5: Skipped (insufficient information)
#
# Strategy 6: Kahn[Author] AND 2006[Date - Publication]
# Search results: 339 articles found
#
#   Result 1: PubMed ID 17167471
#   Article title: Mechanisms linking obesity to insulin resistance and type 2 diabetes.
#   No PMC ID available
#
#   Result 2: PubMed ID 17145742
#   Article title: Glycemic durability of rosiglitazone, metformin, or glyburide monotherapy.
#   No PMC ID available
#
#   Result 3: PubMed ID 16847085
#   Article title: Epidemiology of human metapneumovirus.
#   PMC ID: PMC1539100
# Downloaded: ./pdf_downloads/PMC1539100.pdf
#   Downloaded PDF: ./pdf_downloads/PMC1539100.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Kahn, S. E., Hull, R. L. & Utzschneider, K. M. Mechanisms linking obesity to insulin resistance and type 2 diabetes. Nature 444, 840–6 (2006)..pdf
#
#   Result 4: PubMed ID 16967063
#   Article title: [Corticosteroids in the treatment of HELLP-syndrome?].
#   No PMC ID available
#
#   Result 5: PubMed ID 16788534
#   Article title: [Orbital blow-out fractures].
#   No PMC ID available
#
#   Result 6: PubMed ID 16374217
#   Article title: Sexually transmitted diseases in incarcerated adolescents.
#   No PMC ID available
#
#   Result 7: PubMed ID 17197009
#   Article title: The insecticidal potential of scorpion beta-toxins.
#   No PMC ID available
#
#   Result 8: PubMed ID 16470161
#   Article title: The widening scope of coronaviruses.
#   No PMC ID available
#
#   Result 9: PubMed ID 16475040
#   Article title: The post-thrombotic syndrome: the forgotten morbidity of deep venous thrombosis.
#   No PMC ID available
#
#   Result 10: PubMed ID 16968800
#   Article title: Review: The role of insulin resistance in nonalcoholic fatty liver disease.
#   No PMC ID available
#
#   Result 11: PubMed ID 17179453
#   Article title: The incidentalome.
#   No PMC ID available
#
#   Result 12: PubMed ID 16462679
#   Article title: [Diagnosis of non-parasitic hypereosinophilia].
#   No PMC ID available
#
#   Result 13: PubMed ID 16823474
#   Article title: Glucose transport and sensing in the maintenance of glucose homeostasis and metabolic harmony.
#   PMC ID: PMC1483149
# Downloaded: ./pdf_downloads/PMC1483149.pdf
#   Downloaded PDF: ./pdf_downloads/PMC1483149.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Kahn, S. E., Hull, R. L. & Utzschneider, K. M. Mechanisms linking obesity to insulin resistance and type 2 diabetes. Nature 444, 840–6 (2006)..pdf
#
#   Result 14: PubMed ID 17093476
#   Article title: Patenting race.
#   No PMC ID available
#
#   Result 15: PubMed ID 16584956
#   Article title: Trends in geriatric emergency medicine.
#   No PMC ID available
#
#   Result 16: PubMed ID 17092565
#   Article title: Atypical depression, somatic depression and anxious depression in women: are they gender-preferred phenotypes?
#   No PMC ID available
#
#   Result 17: PubMed ID 16946422
#   Article title: Business training.
#   No PMC ID available
#
#   Result 18: PubMed ID 17412156
#   Article title: Building virtual communities of practice.
#   No PMC ID available
#
#   Result 19: PubMed ID 16926641
#   Article title: Frequency and determinants of the postthrombotic syndrome after venous thromboembolism.
#   No PMC ID available
#
#   Result 20: PubMed ID 16172608
#   Article title: Homocysteine, methylenetetrahydrofolate reductase and risk of schizophrenia: a meta-analysis.
#   No PMC ID available
# Strategy 7: Skipped (insufficient information)
#
# Strategy 8: Kahn, S. E., Hull, R. L. & Utzschneider, K. M.
# Search results: 15 articles found
#
#   Result 1: PubMed ID 17167471
#   Article title: Mechanisms linking obesity to insulin resistance and type 2 diabetes.
#   No PMC ID available
#
#   Result 2: PubMed ID 19326096
#   Article title: The beta cell lesion in type 2 diabetes: there has to be a primary functional abnormality.
#   PMC ID: PMC2737455
# Downloaded: ./pdf_downloads/PMC2737455.pdf
#   Downloaded PDF: ./pdf_downloads/PMC2737455.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Kahn, S. E., Hull, R. L. & Utzschneider, K. M. Mechanisms linking obesity to insulin resistance and type 2 diabetes. Nature 444, 840–6 (2006)..pdf
#
#   Result 3: PubMed ID 15504967
#   Article title: Impact of intra-abdominal fat and age on insulin sensitivity and beta-cell function.
#   No PMC ID available
#
#   Result 4: PubMed ID 16143861
#   Article title: Resistin is not associated with insulin sensitivity or the metabolic syndrome in humans.
#   No PMC ID available
#
#   Result 5: PubMed ID 15677490
#   Article title: A reduced-fat diet and aerobic exercise in Japanese Americans with impaired glucose tolerance decreases intra-abdominal fat and improves insulin sensitivity but not beta-cell function.
#   No PMC ID available
#
#   Result 6: PubMed ID 17222388
#   Article title: Glucose- and time-dependence of islet amyloid formation in vitro.
#   PMC ID: PMC1831460
# Downloaded: ./pdf_downloads/PMC1831460.pdf
#   Downloaded PDF: ./pdf_downloads/PMC1831460.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Kahn, S. E., Hull, R. L. & Utzschneider, K. M. Mechanisms linking obesity to insulin resistance and type 2 diabetes. Nature 444, 840–6 (2006)..pdf
#
#   Result 7: PubMed ID 17141914
#   Article title: Superiority of the Modification of Diet in Renal Disease equation over the Cockcroft-Gault equation in screening for impaired kidney function in Japanese Americans.
#   PMC ID: PMC1995414
#   PDF already downloaded for PMC ID: PMC1995414
#
#   Result 8: PubMed ID 17259373
#   Article title: Identification of the amyloid-degrading enzyme neprilysin in mouse islets and potential role in islet amyloidogenesis.
#   No PMC ID available
#
#   Result 9: PubMed ID 15899941
#   Article title: Genetic background determines the extent of islet amyloid formation in human islet amyloid polypeptide transgenic mice.
#   No PMC ID available
#
#   Result 10: PubMed ID 17327340
#   Article title: Progressive loss of beta-cell function leads to worsening glucose tolerance in first-degree relatives of subjects with type 2 diabetes.
#   No PMC ID available
#
#   Result 11: PubMed ID 15937671
#   Article title: Dietary-fat-induced obesity in mice results in beta cell hyperplasia but not increased insulin release: evidence for specificity of impaired beta cell adaptation.
#   No PMC ID available
#
#   Result 12: PubMed ID 16443887
#   Article title: Impact of differences in fasting glucose and glucose tolerance on the hyperbolic relationship between insulin sensitivity and insulin responses.
#   No PMC ID available
#
#   Result 13: PubMed ID 16936156
#   Article title: Gestational diabetes mellitus increases the risk of cardiovascular disease in women with a family history of type 2 diabetes.
#   No PMC ID available
#
#   Result 14: PubMed ID 15277390
#   Article title: Intra-abdominal fat is a major determinant of the National Cholesterol Education Program Adult Treatment Panel III criteria for the metabolic syndrome.
#   No PMC ID available
#
#   Result 15: PubMed ID 15983227
#   Article title: Long-term treatment with rosiglitazone and metformin reduces the extent of, but does not prevent, islet amyloid deposition in mice expressing the gene for human islet amyloid polypeptide.
#   No PMC ID available
# All strategies exhausted. No matching PDF found.
# Processing: Van Gaal, L. F., Mertens, I. L. & De Block, C. E. Mechanisms linking obesity with cardiovascular disease. Nature 444, 875–80 (2006).
#
# Processing reference: Van Gaal, L. F., Mertens, I. L. & De Block, C. E. Mechanisms linking obesity with cardiovascular disease. Nature 444, 875–80 (2006).
# Extracted info: {
#   "title": "",
#   "authors": "Van",
#   "year": "2006",
#   "doi": ""
# }
# Strategy 1: Skipped (insufficient information)
# Strategy 2: Skipped (insufficient information)
# Strategy 3: Skipped (insufficient information)
#
# Strategy 4: Van[Author] AND 2006[Date - Publication]
# Search results: 49 articles found
#
#   Result 1: PubMed ID 16551535
#   Article title: Microbial synthesis of poly(epsilon-lysine) and its various applications.
#   No PMC ID available
#
#   Result 2: PubMed ID 16458564
#   Article title: Etiology and epidemiology of diarrhea in children in Hanoi, Vietnam.
#   No PMC ID available
#
#   Result 3: PubMed ID 16380330
#   Article title: Epidemiology and treatment of amebiasis in Hué, Vietnam.
#   No PMC ID available
#
#   Result 4: PubMed ID 16477032
#   Article title: Variable host-pathogen compatibility in Mycobacterium tuberculosis.
#   PMC ID: PMC1413851
# Downloaded: ./pdf_downloads/PMC1413851.pdf
#   Downloaded PDF: ./pdf_downloads/PMC1413851.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Van Gaal, L. F., Mertens, I. L. & De Block, C. E. Mechanisms linking obesity with cardiovascular disease. Nature 444, 875–80 (2006)..pdf
#
#   Result 5: PubMed ID 16649956
#   Article title: Patterns of HIV prevalence and HIV risk behaviors among injection drug users prior to and 24 months following implementation of cross-border HIV prevention interventions in northern Vietnam and southern China.
#   No PMC ID available
#
#   Result 6: PubMed ID 16705071
#   Article title: Monosomy for the X-chromosome is associated with an atherogenic lipid profile.
#   No PMC ID available
#
#   Result 7: PubMed ID 16507631
#   Article title: Growth hormone treatment and aortic dimensions in Turner syndrome.
#   No PMC ID available
#
#   Result 8: PubMed ID 16927632
#   Article title: Clinical and laboratory findings at initial diagnosis in pediatric Graves' disease in Taiwan.
#   No PMC ID available
#
#   Result 9: PubMed ID 17125007
#   Article title: Estimation of non-fatal road traffic injuries in Thai Nguyen, Vietnam using capture-recapture method.
#   No PMC ID available
#
#   Result 10: PubMed ID 17093498
#   Article title: Expression of the self-marker CD47 on dendritic cells governs their trafficking to secondary lymphoid organs.
#   PMC ID: PMC1679770
# Downloaded: ./pdf_downloads/PMC1679770.pdf
#   Downloaded PDF: ./pdf_downloads/PMC1679770.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Van Gaal, L. F., Mertens, I. L. & De Block, C. E. Mechanisms linking obesity with cardiovascular disease. Nature 444, 875–80 (2006)..pdf
#
#   Result 11: PubMed ID 16478752
#   Article title: The impact of experimental design on assessing mechanism-based inactivation of CYP2D6 by MDMA (Ecstasy).
#   No PMC ID available
#
#   Result 12: PubMed ID 17238854
#   Article title: Renal function and histology in kidney transplant patients receiving tacrolimus and sirolimus or mycophenolate mofetil.
#   No PMC ID available
#
#   Result 13: PubMed ID 16876893
#   Article title: Rational drug design via intrinsically disordered protein.
#   No PMC ID available
#
#   Result 14: PubMed ID 16609345
#   Article title: Prolongation of the cardiac QTc interval in Turner syndrome.
#   No PMC ID available
#
#   Result 15: PubMed ID 16707143
#   Article title: Socio-economic status inequality and major causes of death in adults: a 5-year follow-up study in rural Vietnam.
#   No PMC ID available
#
#   Result 16: PubMed ID 16882719
#   Article title: Structure of the nuclear exosome component Rrp6p reveals an interplay between the active site and the HRDC domain.
#   PMC ID: PMC2131688
# Downloaded: ./pdf_downloads/PMC2131688.pdf
#   Downloaded PDF: ./pdf_downloads/PMC2131688.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Van Gaal, L. F., Mertens, I. L. & De Block, C. E. Mechanisms linking obesity with cardiovascular disease. Nature 444, 875–80 (2006)..pdf
#
#   Result 17: PubMed ID 16807071
#   Article title: Aberrant methylation of CDH13 gene in nasopharyngeal carcinoma could serve as a potential diagnostic biomarker.
#   No PMC ID available
#
#   Result 18: PubMed ID 17015510
#   Article title: Prolonged rate-corrected QT interval and other electrocardiogram abnormalities in girls with Turner syndrome.
#   No PMC ID available
#
#   Result 19: PubMed ID 16924236
#   Article title: The role of 5' untranslated region in translational suppression of OKL38 mRNA in hepatocellular carcinoma.
#   No PMC ID available
#
#   Result 20: PubMed ID 16511355
#   Article title: Oligomeric structure of the ATP-dependent protease La (Lon) of Escherichia coli.
#   No PMC ID available
# Strategy 5: Skipped (insufficient information)
#
# Strategy 6: Van[Author] AND 2006[Date - Publication]
# Search results: 49 articles found
#
#   Result 1: PubMed ID 16551535
#   Article title: Microbial synthesis of poly(epsilon-lysine) and its various applications.
#   No PMC ID available
#
#   Result 2: PubMed ID 16458564
#   Article title: Etiology and epidemiology of diarrhea in children in Hanoi, Vietnam.
#   No PMC ID available
#
#   Result 3: PubMed ID 16380330
#   Article title: Epidemiology and treatment of amebiasis in Hué, Vietnam.
#   No PMC ID available
#
#   Result 4: PubMed ID 16477032
#   Article title: Variable host-pathogen compatibility in Mycobacterium tuberculosis.
#   PMC ID: PMC1413851
#   PDF already downloaded for PMC ID: PMC1413851
#
#   Result 5: PubMed ID 16649956
#   Article title: Patterns of HIV prevalence and HIV risk behaviors among injection drug users prior to and 24 months following implementation of cross-border HIV prevention interventions in northern Vietnam and southern China.
#   No PMC ID available
#
#   Result 6: PubMed ID 16705071
#   Article title: Monosomy for the X-chromosome is associated with an atherogenic lipid profile.
#   No PMC ID available
#
#   Result 7: PubMed ID 16507631
#   Article title: Growth hormone treatment and aortic dimensions in Turner syndrome.
#   No PMC ID available
#
#   Result 8: PubMed ID 16927632
#   Article title: Clinical and laboratory findings at initial diagnosis in pediatric Graves' disease in Taiwan.
#   No PMC ID available
#
#   Result 9: PubMed ID 17125007
#   Article title: Estimation of non-fatal road traffic injuries in Thai Nguyen, Vietnam using capture-recapture method.
#   No PMC ID available
#
#   Result 10: PubMed ID 17093498
#   Article title: Expression of the self-marker CD47 on dendritic cells governs their trafficking to secondary lymphoid organs.
#   PMC ID: PMC1679770
#   PDF already downloaded for PMC ID: PMC1679770
#
#   Result 11: PubMed ID 16478752
#   Article title: The impact of experimental design on assessing mechanism-based inactivation of CYP2D6 by MDMA (Ecstasy).
#   No PMC ID available
#
#   Result 12: PubMed ID 17238854
#   Article title: Renal function and histology in kidney transplant patients receiving tacrolimus and sirolimus or mycophenolate mofetil.
#   No PMC ID available
#
#   Result 13: PubMed ID 16876893
#   Article title: Rational drug design via intrinsically disordered protein.
#   No PMC ID available
#
#   Result 14: PubMed ID 16609345
#   Article title: Prolongation of the cardiac QTc interval in Turner syndrome.
#   No PMC ID available
#
#   Result 15: PubMed ID 16707143
#   Article title: Socio-economic status inequality and major causes of death in adults: a 5-year follow-up study in rural Vietnam.
#   No PMC ID available
#
#   Result 16: PubMed ID 16882719
#   Article title: Structure of the nuclear exosome component Rrp6p reveals an interplay between the active site and the HRDC domain.
#   PMC ID: PMC2131688
#   PDF already downloaded for PMC ID: PMC2131688
#
#   Result 17: PubMed ID 16807071
#   Article title: Aberrant methylation of CDH13 gene in nasopharyngeal carcinoma could serve as a potential diagnostic biomarker.
#   No PMC ID available
#
#   Result 18: PubMed ID 17015510
#   Article title: Prolonged rate-corrected QT interval and other electrocardiogram abnormalities in girls with Turner syndrome.
#   No PMC ID available
#
#   Result 19: PubMed ID 16924236
#   Article title: The role of 5' untranslated region in translational suppression of OKL38 mRNA in hepatocellular carcinoma.
#   No PMC ID available
#
#   Result 20: PubMed ID 16511355
#   Article title: Oligomeric structure of the ATP-dependent protease La (Lon) of Escherichia coli.
#   No PMC ID available
# Strategy 7: Skipped (insufficient information)
#
# Strategy 8: Van
# Search results: 139660 articles found
#
#   Result 1: PubMed ID 29323775
#   Article title: Van't Hoff analysis in chiral chromatography.
#   No PMC ID available
#
#   Result 2: PubMed ID 30035938
# No article details found for PubMed ID: 30035938
#   Failed to fetch article details
#
#   Result 3: PubMed ID 34731847
#   Article title: 2D van der Waals materials for ultrafast pulsed fiber lasers: review and prospect.
#   No PMC ID available
#
#   Result 4: PubMed ID 33612287
#   Article title: The veiled intimacy between neurology and Vincent van Gogh.
#   No PMC ID available
#
#   Result 5: PubMed ID 35190638
#   Article title: Van der Pol model in two-delay differential equation representation.
#   PMC ID: PMC8861040
# Downloaded: ./pdf_downloads/PMC8861040.pdf
#   Downloaded PDF: ./pdf_downloads/PMC8861040.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Van Gaal, L. F., Mertens, I. L. & De Block, C. E. Mechanisms linking obesity with cardiovascular disease. Nature 444, 875–80 (2006)..pdf
#
#   Result 6: PubMed ID 33990325
#   Article title: Neutron tomography of Van Leeuwenhoek's microscopes.
#   PMC ID: PMC8121416
# Downloaded: ./pdf_downloads/PMC8121416.pdf
#   Downloaded PDF: ./pdf_downloads/PMC8121416.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Van Gaal, L. F., Mertens, I. L. & De Block, C. E. Mechanisms linking obesity with cardiovascular disease. Nature 444, 875–80 (2006)..pdf
#
#   Result 7: PubMed ID 35393766
# ...
#   No PMC ID available
#
#   Result 19: PubMed ID 30718741
#   Article title: Dietary Niacin Intake Predicts the Decrease of Liver Fat Content During a Lifestyle Intervention.
#   PMC ID: PMC6362104
# Downloaded: ./pdf_downloads/PMC6362104.pdf
#   Downloaded PDF: ./pdf_downloads/PMC6362104.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Stefan, N., Schick, F. & Häring, H.-U. Causes, Characteristics, and Consequences of Metabolically Unhealthy Normal Weight in Humans. Cell Metab. 26, 292–300 (2017)..pdf
#
#   Result 20: PubMed ID 25470709
#   Article title: Ectopic fat in insulin resistance, dyslipidemia, and cardiometabolic disease.
#   No PMC ID available
# All strategies exhausted. No matching PDF found.
# Processing: Blüher, M. Metabolically Healthy Obesity. Endocr. Rev. 41, 405–420 (2020).
#
# Processing reference: Blüher, M. Metabolically Healthy Obesity. Endocr. Rev. 41, 405–420 (2020).
# Extracted info: {
#   "title": "Bl\u00fcher, M. Metabolically Healthy Obesity. Endocr",
#   "authors": "Bl",
#   "year": "2020",
#   "doi": ""
# }
# Strategy 1: Skipped (insufficient information)
#
# Strategy 2: "Blüher, M. Metabolically Healthy Obesity. Endocr"[Title]
# No results found
#
# Strategy 3: Bl[Author] AND 2020[Date - Publication] AND "Blüher, M. Metabolically Healthy Obesity. Endocr"[Title]
# No results found
#
# Strategy 4: Bl[Author] AND 2020[Date - Publication]
# No results found
#
# Strategy 5: Blüher, M. Metabolically Healthy Obesity.[Title] AND 2020[Date - Publication]
# Search results: 2 articles found
#
#   Result 1: PubMed ID 32128581
#   Article title: Metabolically Healthy Obesity.
#   PMC ID: PMC7098708
# Failed to download PDF for PMC ID: PMC7098708, Status Code: 404
#
#   Result 2: PubMed ID 32873909
#   Article title: Circulating cell adhesion molecules in metabolically healthy obesity.
#   PMC ID: PMC7840499
# Downloaded: ./pdf_downloads/PMC7840499.pdf
#   Downloaded PDF: ./pdf_downloads/PMC7840499.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Blüher, M. Metabolically Healthy Obesity. Endocr. Rev. 41, 405–420 (2020)..pdf
#
# Strategy 6: Bl[Author] AND 2020[Date - Publication]
# No results found
#
# Strategy 7: Blüher, M. Metabolically Healthy Obesity. Endocr
# Search results: 1 articles found
#
#   Result 1: PubMed ID 32128581
#   Article title: Metabolically Healthy Obesity.
#   PMC ID: PMC7098708
# Failed to download PDF for PMC ID: PMC7098708, Status Code: 404
#
# Strategy 8: Bl
# Search results: 4405459 articles found
#
#   Result 1: PubMed ID 12921123
#   Article title: Bilirubin adsorption column Medisorba BL-300.
#   No PMC ID available
#
#   Result 2: PubMed ID 19717284
#   Article title: BL-1020, a novel antipsychotic candidate with GABA-enhancing effects: D2 receptor occupancy study in humans.
#   No PMC ID available
#
#   Result 3: PubMed ID 118961
#   Article title: Disodium D-6-[alpha-(1,2,4-triazine-3,5-dione-6-carboxamido)-4-hydroxyphenylacetamido]penicillanate, BL-P1908.
#   No PMC ID available
#
#   Result 4: PubMed ID 15307532
#   Article title: [Sporadic Burkitt's lymphoma (BL) with stomach involvement associated with Helicobacter pylori infection--case report and literature review].
#   No PMC ID available
#
#   Result 5: PubMed ID 984784
#   Article title: Laboratory evaluation of BL-S786, a cephalosporin with broad-spectrum antibacterial activity.
#   PMC ID: PMC429765
# Downloaded: ./pdf_downloads/PMC429765.pdf
#   Downloaded PDF: ./pdf_downloads/PMC429765.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Blüher, M. Metabolically Healthy Obesity. Endocr. Rev. 41, 405–420 (2020)..pdf
#
#   Result 6: PubMed ID 36568642
#   Article title: Who bleeds during elective anterior lumbar surgery?
#   PMC ID: PMC9768351
# Downloaded: ./pdf_downloads/PMC9768351.pdf
#   Downloaded PDF: ./pdf_downloads/PMC9768351.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Blüher, M. Metabolically Healthy Obesity. Endocr. Rev. 41, 405–420 (2020)..pdf
#
#   Result 7: PubMed ID 26313568
#   Article title: Borrelial Lymphocytoma in Children.
#   No PMC ID available
#
#   Result 8: PubMed ID 37781734
#   Article title: Sympathetic transduction at rest and during cold pressor test in young healthy non-Hispanic Black and White women.
#   PMC ID: PMC11178294
# Failed to download PDF for PMC ID: PMC11178294, Status Code: 403
#
#   Result 9: PubMed ID 24291345
#   Article title: Optimization and validation of the TZM-bl assay for standardized assessments of neutralizing antibodies against HIV-1.
#   PMC ID: PMC4040342
# Downloaded: ./pdf_downloads/PMC4040342.pdf
#   Downloaded PDF: ./pdf_downloads/PMC4040342.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Blüher, M. Metabolically Healthy Obesity. Endocr. Rev. 41, 405–420 (2020)..pdf
#
#   Result 10: PubMed ID 21871147
#   Article title: Cannabinoids in postmortem toxicology.
#   No PMC ID available
#
#   Result 11: PubMed ID 29728731
#   Article title: Is Intraoperative Blood Loss Underestimated in Patients Undergoing Laparoscopic Hepatectomy?
#   No PMC ID available
#
#   Result 12: PubMed ID 28129369
#   Article title: Serum Metabolomics of Burkitt Lymphoma Mouse Models.
#   PMC ID: PMC5271368
# Downloaded: ./pdf_downloads/PMC5271368.pdf
#   Downloaded PDF: ./pdf_downloads/PMC5271368.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Blüher, M. Metabolically Healthy Obesity. Endocr. Rev. 41, 405–420 (2020)..pdf
#
#   Result 13: PubMed ID 29797909
#   Article title: [Acupuncture at back-<i>shu</i> points of five <i>zang</i>, Geshu (BL 17) and Shenmen (HT 7) for the treatment of menopausal insomnia].
#   No PMC ID available
#
#   Result 14: PubMed ID 29354992
#   Article title: [Moxibustion at Geshu (BL 17) for diabetic limb arterial obliteration at early stage].
#   No PMC ID available
#
#   Result 15: PubMed ID 21090332
#   Article title: [Effects of electroacupuncture of "Weishu" (BL 21) and "Zhongwan" (CV 12) on serum large molecular metabolites in functional dyspepsia rats].
#   No PMC ID available
#
#   Result 16: PubMed ID 29050420
#   Article title: Iron requirements of broiler breeder hens.
#   No PMC ID available
#
#   Result 17: PubMed ID 33902057
#   Article title: Low-Blood Lymphocyte Number and Lymphocyte Decline as Key Factors in COPD Outcomes: A Longitudinal Cohort Study.
#   No PMC ID available
#
#   Result 18: PubMed ID 3337775
#   Article title: Temporary postthyroidectomy hypocalcemia.
#   No PMC ID available
#
#   Result 19: PubMed ID 24651932
#   Article title: Caloric restriction can improve learning ability in C57/BL mice via regulation of the insulin-PI3K/Akt signaling pathway.
#   No PMC ID available
#
#   Result 20: PubMed ID 4790575
#   Article title: Microbiological properties of a new cephalosporin, BL-S 339: 7-(phenylacetimidoyl-aminoacetamido)-3-(2-methyl-1,3,4-thiadiazol-5-ylthiomethyl)ceph-3-em-4-carboxylic acid.
#   PMC ID: PMC444358
# Downloaded: ./pdf_downloads/PMC444358.pdf
#   Downloaded PDF: ./pdf_downloads/PMC444358.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Blüher, M. Metabolically Healthy Obesity. Endocr. Rev. 41, 405–420 (2020)..pdf
# All strategies exhausted. No matching PDF found.
# Processing: Shah, N. R. & Braverman, E. R. Measuring adiposity in patients: the utility of body mass index (BMI), percent body fat, and leptin. PLoS One 7, e33308 (2012).
#
# Processing reference: Shah, N. R. & Braverman, E. R. Measuring adiposity in patients: the utility of body mass index (BMI), percent body fat, and leptin. PLoS One 7, e33308 (2012).
# Extracted info: {
#   "title": "",
#   "authors": "Shah, N. R. & Braverman, E. R.",
#   "year": "2012",
#   "doi": ""
# }
# Strategy 1: Skipped (insufficient information)
# Strategy 2: Skipped (insufficient information)
# Strategy 3: Skipped (insufficient information)
#
# Strategy 4: Shah, N. R. & Braverman, E. R.[Author] AND 2012[Date - Publication]
# Search results: 1 articles found
#
#   Result 1: PubMed ID 22485140
#   Article title: Measuring adiposity in patients: the utility of body mass index (BMI), percent body fat, and leptin.
#   PMC ID: PMC3317663
# Downloaded: ./pdf_downloads/PMC3317663.pdf
#   Downloaded PDF: ./pdf_downloads/PMC3317663.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Shah, N. R. & Braverman, E. R. Measuring adiposity in patients the utility of body mass index (BMI), percent body fat, and leptin. PLoS One 7, e33308 (2012)..pdf
# Strategy 5: Skipped (insufficient information)
#
# Strategy 6: Shah[Author] AND 2012[Date - Publication]
# Search results: 3087 articles found
#
#   Result 1: PubMed ID 23162303
#   Article title: Smith-Lemli-Opitz-syndrome.
#   PMC ID: PMC3491301
# Downloaded: ./pdf_downloads/PMC3491301.pdf
#   Downloaded PDF: ./pdf_downloads/PMC3491301.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Shah, N. R. & Braverman, E. R. Measuring adiposity in patients the utility of body mass index (BMI), percent body fat, and leptin. PLoS One 7, e33308 (2012)..pdf
#
#   Result 2: PubMed ID 23904821
#   Article title: Laser resurfacing pearls.
#   PMC ID: PMC3580978
# Downloaded: ./pdf_downloads/PMC3580978.pdf
#   Downloaded PDF: ./pdf_downloads/PMC3580978.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Shah, N. R. & Braverman, E. R. Measuring adiposity in patients the utility of body mass index (BMI), percent body fat, and leptin. PLoS One 7, e33308 (2012)..pdf
#
#   Result 3: PubMed ID 23199400
#   Article title: Prevention of influenza in healthy children.
#   PMC ID: PMC3763239
# Downloaded: ./pdf_downloads/PMC3763239.pdf
#   Downloaded PDF: ./pdf_downloads/PMC3763239.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Shah, N. R. & Braverman, E. R. Measuring adiposity in patients the utility of body mass index (BMI), percent body fat, and leptin. PLoS One 7, e33308 (2012)..pdf
#
#   Result 4: PubMed ID 23275145
#   Article title: Is there any role for resuscitative emergency department thoracotomy in blunt trauma?
#   PMC ID: PMC3598040
# Downloaded: ./pdf_downloads/PMC3598040.pdf
#   Downloaded PDF: ./pdf_downloads/PMC3598040.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Shah, N. R. & Braverman, E. R. Measuring adiposity in patients the utility of body mass index (BMI), percent body fat, and leptin. PLoS One 7, e33308 (2012)..pdf
#
#   Result 5: PubMed ID 23177407
#   Article title: Office-based laryngeal procedures.
#   No PMC ID available
#
#   Result 6: PubMed ID 23281517
#   Article title: Molecular basis of intervertebral disc degeneration.
#   No PMC ID available
#
#   Result 7: PubMed ID 23153753
#   Article title: Cervical lymph node evaluation and diagnosis.
#   No PMC ID available
#
#   Result 8: PubMed ID 23502198
#   Article title: Spondylolisthesis: a pictorial review.
#   No PMC ID available
#
#   Result 9: PubMed ID 23279845
#   Article title: Interaction between glutathione and apoptosis in systemic lupus erythematosus.
#   PMC ID: PMC3625500
# Downloaded: ./pdf_downloads/PMC3625500.pdf
#   Downloaded PDF: ./pdf_downloads/PMC3625500.pdf
#   Verification failed. Moved to: ./rejected_pdfs/Shah, N. R. & Braverman, E. R. Measuring adiposity in patients the utility of body mass index (BMI), percent body fat, and leptin. PLoS One 7, e33308 (2012)..pdf
#
#   Result 10: PubMed ID 23238463
#   Article title: 11β-Hydroxysteroid dehydrogenase type 1: potential therapeutic target for metabolic syndrome.
#   No PMC ID available
#
#   Result 11: PubMed ID 23319187
#   Article title: Established and emerging variants of glioblastoma multiforme: review of morphological and molecular features.
#   No PMC ID available
#
#   Result 12: PubMed ID 23235613
#   Article title: Extraction of primary (baby) teeth for unerupted palatally displaced permanent canine teeth in children.
#   No PMC ID available
#
#   Result 13: PubMed ID 23269072
#   Article title: Current preclinical models for the advancement of translational bladder cancer research.
#   No PMC ID available
#
#   Result 14: PubMed ID 23257181
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 223
#     220     print(f"Results saved to {csv_output_file}")
#     222 if __name__ == '__main__':
# --> 223     main()
#
# Cell In[19], line 205, in main()
#     202 print(f"Processing: {ref}")
#     203 ref_info = extract_info(ref)
# --> 205 pdf_filename = search_and_download(ref_info, ref, output_folder, rejected_folder, downloaded_pmcs)
#     207 if pdf_filename:
#     208     results.append({'Reference': ref, 'Downloaded': 'Yes', 'Reason': 'PDF downloaded, verified, and renamed', 'Filename': os.path.basename(pdf_filename)})
#
# Cell In[19], line 151, in search_and_download(ref_info, reference, output_folder, rejected_folder, downloaded_pmcs)
#     149 for j, pubmed_id in enumerate(search_results['IdList']):
#     150     print(f"\n  Result {j+1}: PubMed ID {pubmed_id}")
# --> 151     article = fetch_article_details(pubmed_id)
#     152     if article:
#     153         article_title = article['MedlineCitation']['Article']['ArticleTitle']
#
# Cell In[19], line 65, in fetch_article_details(pubmed_id)
#      63 try:
#      64     handle = Entrez.efetch(db='pubmed', id=pubmed_id, rettype='xml', retmode='xml')
# ---> 65     records = Entrez.read(handle)
#      66     handle.close()
#      67     if records['PubmedArticle']:
#
# File ~/miniconda3/envs/pubmed/lib/python3.10/site-packages/Bio/Entrez/__init__.py:529, in read(source, validate, escape, ignore_errors)
#     526 from .Parser import DataHandler
#     528 handler = DataHandler(validate, escape, ignore_errors)
# --> 529 record = handler.read(source)
#     530 return record
#
# File ~/miniconda3/envs/pubmed/lib/python3.10/site-packages/Bio/Entrez/Parser.py:405, in DataHandler.read(self, source)
#     403     raise TypeError("file should be opened in binary mode")
#     404 try:
# --> 405     self.parser.ParseFile(stream)
#     406 except expat.ExpatError as e:
#     407     if self.parser.StartElementHandler:
#     408         # We saw the initial <!xml declaration, so we can be sure that
#     409         # we are parsing XML data. Most likely, the XML file is
#     410         # corrupted.
#
# File ~/miniconda3/envs/pubmed/lib/python3.10/http/client.py:460, in HTTPResponse.read(self, amt)
#     457     return b""
#     459 if self.chunked:
# --> 460     return self._read_chunked(amt)
#     462 if amt is not None:
#     463     if self.length is not None and amt > self.length:
#     464         # clip the read to the "end of response"
#
# File ~/miniconda3/envs/pubmed/lib/python3.10/http/client.py:583, in HTTPResponse._read_chunked(self, amt)
#     581 try:
#     582     while True:
# --> 583         chunk_left = self._get_chunk_left()
#     584         if chunk_left is None:
#     585             break
#
# File ~/miniconda3/envs/pubmed/lib/python3.10/http/client.py:566, in HTTPResponse._get_chunk_left(self)
#     564     self._safe_read(2)  # toss the CRLF at the end of the chunk
#     565 try:
# --> 566     chunk_left = self._read_next_chunk_size()
#     567 except ValueError:
#     568     raise IncompleteRead(b'')
#
# File ~/miniconda3/envs/pubmed/lib/python3.10/http/client.py:526, in HTTPResponse._read_next_chunk_size(self)
#     524 def _read_next_chunk_size(self):
#     525     # Read the next chunk size from the file
# --> 526     line = self.fp.readline(_MAXLINE + 1)
#     527     if len(line) > _MAXLINE:
#     528         raise LineTooLong("chunk size")
#
# File ~/miniconda3/envs/pubmed/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/miniconda3/envs/pubmed/lib/python3.10/ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/pubmed/lib/python3.10/ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:
